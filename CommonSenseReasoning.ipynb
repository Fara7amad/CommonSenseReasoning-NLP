# %% [markdown]
# Importing Libraries

# %%
import json
import numpy as np
import gensim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# from gensim.models import FastText, Word2Vec, KeyedVectors
# from gensim.models.word2vec import Word2Vec
# from gensim.scripts.glove2word2vec import glove2word2vec
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Discovering the models available:

# %%
import gensim.downloader

print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %% [markdown]
# Loadind & discovering the data

# %%
# Load the data
data = []
with open(r'D:\4th year 2nd semester\NLP\Assignment-2 Common Sense Reasoning\train_rand_split.jsonl', 'r') as f:
    for line in f:
        json_object = json.loads(line)
        data.append(json_object)

# %%
questions = [item['question']['question_concept'] for item in data]

# %%
topics = [item['question']['question_concept'] for item in data]
print(len((topics)))
print(len(set(topics)))
# Out:
# 9741
# 2151

# %% [markdown]
# Baseline

# %%
import random

def baseline_random_guessing(data):
    # List to store predicted answers
    predicted_answers = []
    
    # Iterate over each question in the dataset
    for item in data:
        # Generate a random guess (choose a random choice)
        random_guess = random.choice(item['question']['choices'])
        # Append the random guess to the list of predicted answers
        predicted_answers.append(random_guess['label'])
    
    return predicted_answers

def calculate_accuracy(predictions, true_labels):
    # Count the number of correct predictions
    num_correct = sum(1 for pred, true in zip(predictions, true_labels) if pred == true)
    # Calculate accuracy
    accuracy = num_correct / len(predictions)
    return accuracy

true_labels=[item['answerKey'] for item in data]
# Get random predictions
random_predictions = baseline_random_guessing(data)
# Calculate accuracy
accuracy = calculate_accuracy(random_predictions, true_labels)
print("Baseline (Random Guessing) Accuracy:", accuracy)
# Out:
# Baseline (Random Guessing) Accuracy: 0.1999794682270814

# %% [markdown]
# Seeking the topics

# %%
unique_items_set=((set(topics)))

for item in unique_items_set:
    print(item)
# Out:
# cooking
# possible
# ventilation system
# television
# cleaning house
# indian restaurant
# microphone boom
# shampoo
# copulate
# punish
# playing games
# wine list
# teakettle
# shoes
# clouds
# sheep
# return to work
# escape
# work
# cashing in
# killing
# need
# socialising
# art
# taking final exams
# harmonica
# niece
# check
# vessel
# shed
# young
# coin
# heifer
# movies
# product
# party
# lover
# harp
# opening business
# small dog
# blood
# disk
# faith
# steel cable
# urinating
# playing violin
# island
# god
# clavichord
# volume
# potatoes
# teenagers
# die
# jogging
# reading
# kingdom
# running after ball
# sleep
# fast
# noise
# subway stop
# fitting room
# paper clip
# rosebush
# stand in line
# fast food restaurant
# blowfish
# drinking
# having sex
# live life
# watch tv
# ruler
# mighty
# centavo
# rubber
# kleenex
# cannon
# bowl
# bible
# listen
# talking
# antibiotic
# piccolo
# litter
# going jogging
# twist
# hate
# eat breakfast
# laser
# ski
# remember
# have lunch
# leaves
# dishes
# cheap
# rest
# billfold
# greed
# luggage
# dentist
# stick
# trumpet
# paperwork
# helium
# saucer
# court
# go to school
# laconic
# solidity
# wheat
# making friends
# perfect
# inch
# knight
# potato
# reaching tentative agreement
# everybody
# new
# playing piano
# being in love
# fork
# learning about world
# clock
# counter
# train
# dining room
# ear
# note
# fight inflation
# back
# football field
# bus station
# joy
# forgive
# profit
# fleas
# make bread
# cheese
# led
# corner shop
# voice
# playroom
# mouthpiece
# fighting inflation
# isle
# bat
# carrots
# gambling
# feather
# analyse
# cold
# townhouse
# title
# key
# violin
# kuwait
# eating too much
# poor
# stool
# llano estacado
# electric motor
# cook dinner
# boredom
# contemplating
# attache case
# musical instrument
# going on vacation
# going somewhere
# car
# chatting with friends
# writer
# every person
# stabbing to death
# bridge
# compost
# tap
# container
# elephants
# index card
# card catalog
# playing cards
# eating lunch
# virginia
# lint
# politicians
# build
# comfort friend
# procreating
# moss
# tables
# going to sleep
# tires
# reproduce
# armchair
# allow
# analysing
# curtain
# hospital
# needlepoint
# exhaustion
# knitting
# numbers
# day
# hotel room
# common
# shade
# spectator
# standing in line
# nails
# petrol
# abandon
# real estate agent
# sofabed
# bungalow
# breathing fresh air
# needle
# sofa
# frying pan
# rock
# terrace
# copy
# parlor
# wing
# line
# fish
# refrigerator
# back courtyard
# loving another
# jog
# turn
# divider
# razor
# iron
# calendar
# speaker
# lobby
# hot
# farmland
# reception desk
# go to sleep
# seat
# faucet
# elastic
# performer
# families
# little
# drink
# ocean
# container cup
# telephone directory
# lawn mower
# snare drum
# heat source
# weather
# neck
# eatery
# cup
# watching television
# study
# orchestra pit
# side chair
# large container
# saucepan
# giving assistance
# plain
# hinged door
# homeless person
# run out of steam
# organ
# go to bed
# moistener
# grain of sand
# shareholder
# back yard
# gardner
# safe
# amiable
# king
# discovering truth
# balloon
# straight
# getting drunk
# factory
# wreck
# salad bowl
# vacation
# confusion
# dead body
# bicycle
# expressing yourself
# lawyer
# competing against
# glad
# steak house
# garden
# aberdeen
# watching tv
# driving
# full
# money
# instituting civil action
# authors
# saw
# south america
# diamonds
# basketball court
# old stuff
# judging
# condo
# drinks
# cargo
# sports
# attack
# pure
# fact
# changing room
# engine
# spirit
# flooring
# lights
# earth
# have rest
# baseball
# insulation
# shock
# fortune
# opponent
# opera glasses
# mustard
# sporting goods store
# ignorance
# crab
# basketball
# cemetery
# strap
# competing
# hairbrush
# beer
# shower
# electric razor
# creativity
# tote bag
# express information
# leg
# seating
# drinking alcohol
# standing up
# creek
# singing
# wedding chapel
# plant
# address label
# read
# lake
# familiar
# parking lot
# night owl
# investor
# army
# tennis court
# hunger
# attending school
# chefs
# gum
# metal rod
# stop standing in
# hiking
# contract
# success
# books
# astronauts
# throat
# bath
# dream
# math
# boxes
# eating
# united states
# pass course
# standing in queue
# hamburgers
# sugar
# farmers
# living
# kill
# cubicle
# stove
# dance
# rule
# automaton
# beam
# heat
# crossroads
# bean
# cleaning
# state highway
# jellyfish
# confirm
# flour
# driftwood
# strong
# answering questions
# pebble
# division
# box office
# often
# tickets
# traveling
# feet
# theater
# getting up early
# value
# drawstring bag
# human
# olives
# doorway
# door with lock
# sword
# sheet of paper
# candy
# government
# squirrel
# mountain
# shopping bag
# drive
# shopping
# animals
# serve customers
# make friends
# pretending
# north carolina
# dry storage
# ranch house
# kids
# committing perjury
# banker
# bomb
# secular
# koala
# union
# garbage waste
# stone
# cogitating
# typing
# toys
# walking dog
# hydrogen
# glass of milk
# reading newspaper
# running errands
# baby
# waiting for
# storage
# landing
# hamburger
# mouthwash
# comfort
# grocery store
# lose
# garbage
# fans
# coffee
# spending money
# base
# move
# wrestle
# beaver
# washcloth
# dime store
# rich
# foot
# staples
# apples
# foreign
# play games
# knowledge
# distance
# stage
# milky way
# leather
# triangle
# washing clothes
# meteor
# barbecue
# expressway
# marker
# roadway
# pie
# rooms
# politician
# tomatoes
# trash
# magnet
# sadness
# choose
# passageway
# visiting museum
# students
# compete against
# lens
# learn new
# keyboard instrument
# lemur
# native
# wings
# printing on printer
# altar
# saxophone
# quality
# bassoon
# eat vegetables
# confetti
# head
# houses
# trivial
# adults
# fan
# cabbage
# cover
# helping
# most birds
# reception
# stopping being married to
# energy
# couple
# urinate
# understanding better
# question
# monitor wall
# words
# find
# velvet
# skyscraper
# snow
# turnstile
# spout
# call
# cello
# dreaming
# thinking
# lips
# sleeping
# claim
# recording somethign
# cash in
# all mammals
# losing consciousness
# getting wet
# communicate
# hot dogs
# chef
# drunkard
# having heart attack
# desire to learn
# fortis
# paying bills
# gain more land
# prisoner
# electric fan
# chairs
# connect
# taking care of proposals
# stuff
# sitting down
# airplane
# worker
# anemone
# jealousy
# ants
# tile
# trains
# columbia
# contemplate
# cable
# top floor
# stock
# anger
# play piano
# thanking
# flawless
# against
# hair
# honest
# kiss
# vegetable garden
# take stand
# buying christmas presents
# church
# play poker
# attic
# rats
# audience
# paper clips
# airplanes
# going to market
# teddy bear
# diving
# necessary
# runner
# plates
# marble
# read book
# republican

# %% [markdown]
# Choosing & downloading the models:

# %%
# Download the 'glove-wiki-gigaword-300' embeddings
glove_vectors = gensim.downloader.load('glove-wiki-gigaword-300')

# Download the 'fasttext-wiki-news-subwords-300' embeddings
fasttext_vectors = gensim.downloader.load('fasttext-wiki-news-subwords-300')

# Download the  'word2vec-google-news-300' embeddings
word2vec_vectors = gensim.downloader.load('word2vec-google-news-300')

# %% [markdown]
# Exploring the data with embeddings

# %%
def get_word_embedding(word, embedding_model):
    if embedding_model == 'glove':
        if word in glove_vectors:
            return glove_vectors[word]
        else:
            return None
    elif embedding_model == 'fasttext':
        if word in fasttext_vectors:
            return fasttext_vectors[word]
        else:
            return None
    elif embedding_model == 'word2vec':
        if word in word2vec_vectors:
            return word2vec_vectors[word]
        else:
            return None
    else:
        print("Invalid embedding model name")
        return None

# %% [markdown]
# 'Testing stop words Existence'
#
# ----
#
# Results:
#
# 1. Glove & fasttext have all the stopwords
#
# 2. word2vec does not have (a,and,of,to) but have (A, And, Of, To)

# %%
# def test_stop_words_embedding(stop_words, embedding_model):
#     missing_embeddings = []
#     for word in stop_words:
#         embedding = get_word_embedding(word, embedding_model)
#         if embedding is None:
#             missing_embeddings.append(word)
#     return missing_embeddings

def test_stop_words_embedding(stop_words, embedding_model):
    missing_embeddings = []
    for word in stop_words:
        # Check for lowercase version
        embedding = get_word_embedding(word.lower(), embedding_model)
        if embedding is None:
            # If not found, check for uppercase version
            embedding = get_word_embedding(word.upper(), embedding_model)
            if embedding is None:
                missing_embeddings.append(word)
    return missing_embeddings

stop_words = ["a", "an", "and", "are", "as", "at", "be", "but", "by", "for", "if", "in", "into", "is", "it", "no", "not", "of", "on", "or", "such", "that", "the", "their", "then", "there", "these", "they", "this", "to", "was", "will" , "with"]
embedding_model = ["word2vec",'fasttext','glove']  
for model in embedding_model:
    missing_embeddings = test_stop_words_embedding(stop_words, model)
    if missing_embeddings:
        print("Stop words without embeddings in", model, ":", missing_embeddings)
    else:
        print("All stop words have embeddings in", model)
# Out:
# All stop words have embeddings in word2vec
# All stop words have embeddings in fasttext
# All stop words have embeddings in glove

# %% [markdown]
# Discovering the words' existence in the embeddings:

# %%
def test_word_embedding(text_list, embedding_model):
    missing_embeddings = []
    for text in text_list:
        for word in text.split():
            # Check for lowercase version
            embedding = get_word_embedding(word.lower(), embedding_model)
            if embedding is None:
                # If not found, check for uppercase version
                word_upper_first = word[0].upper() + word[1:].lower()
                embedding = get_word_embedding(word_upper_first, embedding_model)
                if embedding is None:
                    missing_embeddings.append(word)
    return missing_embeddings

# %%
questions = [item['question']['stem'] for item in data]
embedding_model = ["word2vec",'fasttext','glove']  
for model in embedding_model:
    missing_embeddings = test_word_embedding(questions, model)
    if missing_embeddings:
        print("Words without embeddings in", model, ":", missing_embeddings)
    else:
        print("All words in questions have embeddings in", model)
# Out:
# Words without embeddings in word2vec : ['blow,', 'change?', 'were.', 'go?', 'go?', 'what?', 'forest,', 'for?', 'cable?', 'bag,', 'it?', 'old,', 'what?', 'pen?', 'located?', 'out?', 'divorce,', 'work?', 'hobby.', 'he?', 'quickly.', 'what?', 'favorite,', 'what?', 'Cajun,', 'he?', 'grill?', 'illness?', 'shopping?', 'menu,', 'feel?', 'to?', 'entrance?', 'what?', 'throttle,', 'what?', 'body,', 'scared.', 'what?', 'errands,', 'had?', 'rest,', 'day?', 'snakes.', 'them?', 'death.', 'them,', 'him.', 'that?', 'what?', 'share,', 'that?', 'places,', 'looking?', 'canals?', 'food?', 'move?', "Mark's", 'thick,', 'what?', 'sun?', 'America?', 'institution?', 'pain?', 'safe?', 'free,', 'microtransactions?', 'accidents?', 'in?', 'accomplish?', "Jame's", 'walked,', 'hot.', 'been?', 'drought,', 'he?', 'skiing?', 'alarm,', 'sensor?', 'lunch,', 'watch,', 'rush?', 'mandatory,', 'TV?', 'work?', 'jacks?', 'duties,', 'what?', 'difficult.', 'mistakes,', 'misinterpretation,', 'uncomfortable,', 'what?,', 'people,', 'out.', 'him?', 'playing?', 'exhaustion?', 'money?', 'have?', 'do?', 'this?', 'drinks,', 'what?', 'sunlight?', 'school?', 'fiddle?', 'ago,', 'what?', 'people?', 'ball?', 'restaurant?', 'at?', 'call,', 'offer?', 'fashion,', 'look?', 'news?', 'tennis?', 'in?', 'college,', 'what?', 'size,', 'miserably.', 'what?', 'consciousness.', 'frightened.', 'this.', 'what?', 'self-important,', 'people?', "workman's", 'compensation,', 'where?', 'project.', 'what?', 'have?', 'read?', 'pencils,', 'go?', 'products,', 'needs?', 'feel?', 'possible,', 'activities?', 'time?', 'cello?', 'flowerS?', 'in?', 'key,', 'what?', 'scary.', 'what?', "city's", 'what?', 'apart?', 'weight?', 'what?', 'onions,', 'cut?', 'hours?', 'regularly,', 'what?', 'do?', 'glad,', 'gloomy,', 'have?', 'what?', 'rest,', 'morning?', 'temple?', 'pollen?', 'house?', 'divorce,', 'end?', 'place?', 'knuckles.', 'bad.', 'what?', 'indoors,', 'what?', "someone's", 'depressed?', 'event,', 'what?', 'person?', 'game,', 'where?', 'heart?', 'foods,', 'suggestions?', 'out,', 'it?', 'place.', 'Sam?', 'something?', 'careful.', 'spool,', 'what?.', 'interview,', 'portray?', 'speech?', 'happiest?', 'where?', 'book,', 'have?', 'ocean?', 'what?', 'be?', 'rock,', 'it?', 'to?', 'year,', 'what?', '"There', '10', 'tree.', 'off.', 'apples."', 'of?', 'food?', 'play?', 'educated?', 'accident.', 'mistake,', 'somewhere.', 'he?', 'games/', 'where?', 'these.', 'out.', 'company.', 'what?', 'cool,', 'where?', 'him,', 'what?', 'country,', 'do?', 'eyepiece?', 'decorations,', 'what?', 'test,', 'what?', 'what?', 'jogging?', 'it?', 'caught?', 'table?', 'what,', 'negligible?', 'city?', 'extinguishers?', 'piano?', 'yourself?', 'couple.', 'longer.', 'reason,', 'what?', 'to?', 'market?', 'glass?', 'time?', "Bob's", 'pavement.', 'shoes,', 'landed,', 'home.', 'run?', 'fashion?', 'competitive.', 'categories?', 'sale.', 'what?', 'well?', 'people?', 'presents?', 'competition?', 'bedroom,', 'seek?', 'to?', 'ficus.', 'home?', 'rug.', 'one.', 'Really,', 'place.', 'run?', 'friends,', 'talking?', 'science?', 'dangers,', 'what?', 'intersection?', 'what?', 'traffic,', 'what?', 'booths?', 'family.', 'it,', 'job.', 'Still,', 'what?', "Alexa's", 'home,', 'guitar.', 'one?', 'into?', 'leaving?', 'evening?', 'stolen?', 'ideas,', 'this?', 'be?', 'housework,', 'this?', 'what?', 'what?', 'themselves?', 'share?', 'stand?', 'backyards?', 'shoe?', 'cards,', 'personal.', 'choose,', 'instead?', 'flight,', 'what?', 'someone?', 'hairpin?', 'field?', 'craft?', 'done?', 'woods,', 'where?', 'humans,', 'all?', 'engineer,', 'what?', 'hungry?', 'museum.', 'there,', 'what?', 'to?', 'things,', 'house.', 'item?', 'stored?', 'family?', 'what?', 'person,', 'what?', 'together,', 'see?', 'tired,', 'do?', 'four-legged', 'complete?', 'it?', 'pencils.', 'more?', 'wood?', 'leg?', 'court,', 'what?', 'eat?', 'outdoors?', 'for?', 'items?', 'name,', "governor's", 'where?', 'album?', 'injury?', 'remote?', 'bus,', 'what?', 'worthless,', 'what?', 'her,', 'friends?', 'sky,', 'what?', 'nearby ...
# Words without embeddings in fasttext : ['blow,', 'change?', 'go?', 'go?', 'what?', 'forest,', 'for?', 'cable?', 'bag,', 'it?', 'old,', 'what?', 'pen?', 'located?', 'out?', 'divorce,', 'work?', 'hobby.', 'he?', "didn't", 'what?', 'favorite,', 'what?', 'Cajun,', 'he?', 'grill?', 'illness?', 'shopping?', 'menu,', 'feel?', 'to?', 'entrance?', 'what?', 'throttle,', 'what?', 'body,', 'what?', 'errands,', 'had?', "could've", 'rest,', 'day?', 'snakes.',
 'cards,', 'choose,', 'instead?', 'flight,', 'what?', 'someone?', 'hairpin?', 'field?', 'craft?', 'done?', 'woods,', 'where?', 'humans,', 'all?', 'engineer,', 'what?', 'hungry?', 'there,', 'what?', 'to?', 'things,', 'item?', 'stored?', 'family?', 'what?', 'person,', 'what?', 'together,', 'see?', 'tired,', 'do?', 'complete?', 'it?', 'pencils.', 'more?', 'wood?', 'leg?', 'court,', 'what?', 'eat?', 'outdoors?', 'for?', 'items?', 'name,', "governor's", 'where?', 'album?', 'injury?', 'remote?', 'bus,', 'what?', 'worthless,', 'what?', 'her,', 'friends?', 'sky,', 'what?', 'nearby,', 'USA?', 'things,', 'what?', 'learning?', 'what?', "pet's", 'this?', 'date,', 'achieve?', 'prices,', 'do?', 'lotion,', 'want?', 'what,', "don't", 'anything?',  ...
# Words without embeddings in glove : ['blow,', 'change?', 'were.', 'go?', 'go?', 'what?', 'forest,', 'for?', 'cable?', 'bag,', 'it?', 'old,', 'what?', 'pen?', 'located?', 'out?', 'divorce,', 'work?', 'hobby.', 'he?', 'quickly.', "didn't", 'what?', 'favorite,', 'what?', 'Cajun,', 'he?', 'grill?', 'illness?', 'shopping?', 'menu,', 'feel?', 'to?', 'entrance?', 'what?', 'throttle,', 'what?', 'body,', 'scared.', 'what?', 'errands,', 'had?', "could've", 'rest,', 'day?', 'snakes.', 'them?', 'death.', 'them,', 'him.', 'that?', 'what?', 'share,', 'that?', 'places,', 'looking?', 'canals?', 'food?', 'move?', "Mark's", 'thick,', 'what?', 'sun?', 'America?', 'institution?', 'pain?', 'safe?', 'free,', "child's", 'microtransactions?', 'accidents?', 'in?', 'accomplish?', "Jame's", 'walked,', 'hot.', 'been?', 'drought,', 'he?', 'skiing?', 'alarm,', 'sensor?', 'lunch,', 'watch,', 'rush?', 'mandatory,', 'TV?', 'work?', 'jacks?', 'duties,', 'what?', 'difficult.', "you're", 'mistakes,', 'misinterpretation,', 'uncomfortable,', 'what?,', 'people,', 'out.', 'him?', 'playing?', 'exhaustion?', 'money?', 'have?', 'do?', 'this?', 'drinks,', 'what?', 'sunlight?', 'school?', 'fiddle?', 'ago,', 'what?', 'people?', 'ball?', 'restaurant?', 'at?', 'call,', 'offer?', 'fashion,', 'look?', 'news?', 'tennis?', 'in?', 'college,', 'what?', 'size,', 'miserably.', 'what?', 'consciousness.', 'frightened.', "didn't", 'this.', 'what?', 'self-important,', 'people?', "workman's", 'compensation,', 'where?', 'project.', 'what?', 'have?', "it's", 'read?', 'pencils,', 'go?', 'products,', 'needs?', 'feel?', 'possible,', 'activities?', 'time?', 'cello?', 'flowerS?', 'in?', 'key,', 'what?', 'scary.', 'what?', "city's", 'what?', 'apart?', 'weight?', 'what?', 'onions,', 'cut?', 'hours?', 'regularly,', 'what?', 'do?', "aren't", 'glad,', 'gloomy,', 'have?', 'what?', 'rest,', 'morning?', 'temple?', 'pollen?', 'house?', "you're", 'divorce,', 'end?', 'place?', 'knuckles.', 'bad.', 'what?', 'indoors,', 'what?', "someone's", 'depressed?', 'event,', 'what?', 'person?', 'game,', "wasn't", 'where?', 'heart?', "I'm", 'foods,', 'suggestions?', 'out,', 'it?', 'place.', 'Sam?', 'something?', "wasn't", 'careful.', 'spool,', 'what?.', 'interview,', 'portray?', 'speech?', 'happiest?', 'where?', 'book,', 'have?', 'ocean?', "weren't", 'what?', 'be?', 'rock,', 'it?', 'to?', 'year,', 'what?', '"There', 'tree.', 'off.', 'apples."', 'of?', 'food?', 'play?', 'educated?', 'accident.', 'mistake,', 'somewhere.', 'he?', 'games/', 'where?', 'these.', 'out.', "didn't", 'company.', 'what?', 'cool,', 'where?', 'him,', 'what?', 'country,', 'do?', "What's", 'eyepiece?', 'decorations,', 'what?', 'test,', 'what?', "they'll", 'what?', 'jogging?', 'it?', 'caught?', 'table?', "isn't", 'what,', 'negligible?', 'city?', 'extinguishers?', 'piano?', 'yourself?', 'couple.', 'longer.', 'reason,', 'what?', 'to?', 'market?', 'glass?', 'time?', "Bob's", 'pavement.', 'shoes,', "didn't", 'landed,', 'home.', 'run?', 'fashion?', 'competitive.', 'categories?', 'sale.', 'what?', 'well?', 'people?', 'chistmas', 'presents?', 'competition?', 'bedroom,', 'seek?', 'to?', 'ficus.', 'home?', 'rug.', 'one.', 'Really,', "didn't", 'place.', 'run?', 'friends,', 'talking?', "one's", 'science?', 'dangers,', 'what?', 'intersection?', 'what?', 'traffic,', 'what?', 'booths?', 'family.', 'it,', 'job.', 'Still,', 'what?', "Alexa's", "couldn't", 'home,', 'guitar.', 'one?', 'into?', 'leaving?', 'evening?', 'stolen?', 'ideas,', 'this?', 'be?', 'housework,', 'this?', "hasn't", 'what?', "you've", "you've", 'what?', 'themselves?', 'share?', 'stand?', 'backyards?', 'shoe?', 'cards,', 'personal.', 'choose,', 'instead?', 'flight,', 'what?', 'someone?', 'hairpin?', 'field?', 'craft?', 'done?', 'woods,', 'where?', 'humans,', 'all?', 'engineer,', 'what?', 'hungry?', 'museum.', 'there,', 'more.', 'what?', 'to?', 'things,', 'house.', 'item?', 'stored?', 'family?', 'what?', 'person,', 'what?', 'together,', 'see?', 'tired,', 'do?', 'complete?', 'it?', 'pencils.', 'more? ...

# %%
def test_choices_embedding(questions, embedding_model):
    missing_embeddings = []
    for question in questions:
        for choice in question:  # Iterate over choices in the question
            for word in choice['text'].split():  # Split the choice text into words
                # Check for lowercase version
                embedding = get_word_embedding(word.lower(), embedding_model)
                if embedding is None:
                    # If not found, check for uppercase version
                    word_upper_first = word[0].upper() + word[1:].lower()
                    embedding = get_word_embedding(word_upper_first, embedding_model)
                    if embedding is None:
                        missing_embeddings.append(word)
    return missing_embeddings

# %%
choices = [item['question']['choices'] for item in data]
for model in embedding_model:
    missing_embeddings_ch = test_choices_embedding(choices, model)
    if missing_embeddings_ch:
        print("Words without embeddings in", model, ":", missing_embeddings_ch)
    else:
        print("All words in questions have embeddings in", model)
# Out:
or's", 'telephonelines', 'healer.', 'yatch', 'topfree', 'badarse', "doctor's", "friend's", "friend's", 'failure..', "bird's", 'i.d', "person's", 'maintopmast', "farmer's", "mammoth's", 'radiotracking', "doctor's", 'obay', "children's", 'earing', "neighbor's", "dog's", "carpenter's", 'belittlement', 'lawyre', "friend's", "friend's", "neighbor's", "friend's", "neighbor's", 'countryfolk', 'moviehall', "grandmother's", "doctor's", 'squarial', 'i.d', "writer's", 'workhour', 'muscians', "neighbor's", 'poormouth', "friend's", 'straightforth', "person's", 'eferendum', 'country’s', 'nonpeaceful', "brother's", "grandma's", "child's", 'sitfast', "person's", 'folkest', "pedestrian's", 'radiotracking', "child's", "bob's", "neighbor's", "girl's", 'comfortness', "doctor's", 'harddisk', "neighbor's", 'musle', 'string.', "person's", "neighbor's", "one's", "neighbor's", 'kindergarden', 'stomech', "friend's", 'splurp', 'sping', 'splog', "boss's", "artist's", "woman's", "they're", "women's", "farmer's", "person's", "killer's", 'smartet', 'carpooler', 'garder', "farmer's", 'wireroom', 'nonelective', "friend's", 'aquarium.', "friend's", "neighbor's", "neighbor's", 'speach', "farmer's", 'cow.', "you'll", "word's", 'dissappeared', 'atation', "one's", "doctor's", 'difnner', 'ebrating', "friend's", 'badarse', "friend's", 'toothrow', "farmer's", "world's", 'resturant', "neighbor's", 'annurism', 'swamplife', 'coverning', "lenin's", 'storebought', "i'm", 'appriciation', 'llaughing', 'ochestra', 'r3al', 'crime.', "person's", 'yatch', 'beautifull', 'cobbed', "cow's", 'parkling', 'coupon.', "neighbor's", 'den.', "bird's", "carpenter's", "bird's", "ocean's", '"hello"', 'possimism', "neighbor's", 'petstore', 'meloncoly', "children's", 'slopewash', "child's", "friend's", "doctor's", "friend's", 'fotograph', "officer's", "lion's", 'dreamworker', 'editer', 'departaments', "doctor's", "friend's", 'luck!', "ship's", "writer's", "you're", 'transmutate', 'hanky.', 'yard.', "writer's", 'desination', 'encylopedia', 'commmunicating', 'lazyness', 'amdends', 'beautifull', "friend's", "neighbor's", "woman's", 'resthold', "son's", "neighbor's", 'gendering', "doctor's", "neighbor's", "neighbor's", 'visions.', "person's", 'asomatous', "calligrapher's", "neighbor's", "god's", 'addidas', 'caretake', 'impoite', ...

# %% [markdown]
# Cleaning questions & choices

# %%
from text_cleaner import clean_text

# %%
# Function to remove specific punctuation marks
def remove_specific_punctuation(text):
    punctuation_marks = "“/!.,?;\""
    for mark in punctuation_marks:
        text = text.replace(mark, "")
    return text
# Extract stems and choices
stems =  [remove_specific_punctuation(item['question']['stem']) for item in data]
choices=[remove_specific_punctuation(choice['text'])for item in data for choice in item['question']['choices']]

# %%
# Clean stems and choices
cleaned_stems = [clean_text(stem) for stem  in stems]
cleaned_choices = [clean_text(choice) for choice in choices]

# %%
embedding_model = ["word2vec",'fasttext','glove']  

for model in embedding_model:
    missing_embeddings_ch = test_word_embedding(cleaned_stems, model)
    if missing_embeddings_ch:
        print("Words without embeddings in", model, ":", missing_embeddings_ch)
    else:
        print("All words in questions have embeddings in", model)
# Out:
# Words without embeddings in word2vec : ['locomote', 'outoing', 'neating', 'Hobokenn', 'omnidiciplinarian', 'fantasied', 'Moraceae', 'weating', 'weating', 'ttown', 'contemn', 'weating', 'DDT', 'Sahmbi', 'Neuroepithelium', 'Meditorranean', 'Potatosol', 'weating', 'weating', 'weating', 'Yooperland', 'weating', 'feating', 'weating', 'opposingly', 'appeating', 'árbol', 'overbeating', 'DRC', 'whaat']
# Words without embeddings in fasttext : ['outoing', 'neating', 'Hobokenn', 'omnidiciplinarian', 'weating', 'weating', 'ttown', 'weating', 'Sahmbi', 'Meditorranean', 'Potatosol', 'weating', 'weating', 'weating', 'Yooperland', 'weating', 'unjammed', 'feating', 'weating', 'opposingly', 'appeating', 'overbeating']
# Words without embeddings in glove : ['locomote', 'outoing', 'neating', 'everyones', 'Hobokenn', 'sleighing', 'omnidiciplinarian', 'cogitating', 'fantasied', 'weating', 'weating', 'cogitating', 'debaucherous', 'ttown', 'contemn', 'weating', 'phoneless', 'apiarist', 'Sahmbi', 'heshe', 'cogitating', 'Neuroepithelium', 'Meditorranean', 'Potatosol', 'weating', 'weating', 'weating', 'Yooperland', 'weating', 'unjammed', 'feating', 'weating', 'opposingly', 'ninteen', 'stero', 'appeating', 'overbeating', 'cogitating', 'orginated', 'posion', 'carboard', 'sleighing', 'whaat']

# %%
for model in embedding_model:
    missing_embeddings_ch = test_word_embedding(cleaned_choices, model)
    if missing_embeddings_ch:
        print("Words without embeddings in", model, ":", missing_embeddings_ch)
    else:
        print("All words in questions have embeddings in", model)
# Out:
# Words without embeddings in word2vec : ['sandplain', 'undestoryable', 'ttown', 'imprevisto', 'weating', 'vadso', 'weating', 'hexachord', 'nightown', 'deliriousness', 'controvertible', 'garderobe', 'uneccentric', 'centimetre', 'nightown', 'squarial', 'straightforth', 'country’s', 'sitfast', 'folkest', 'comfortness', 'toothrow', 'swamplife', 'cobbed', 'slopewash', 'fotograph', 'transmutate', 'twerk', 'asomatous', 'icbm', 'choit', 'potence', 'deepfelt', 'evercookie', 'evercookie', 'alpenstock', 'waterpoint', 'stanine', 'autolock', 'mailcatcher', 'potence', 'thundershock', 'tryhard', 'undivine', 'schlitztown', 'teetotaller', 'topfull', 'straightforth', 'straightforth', 'vacationgoer', 'racecation', 'azawakh', 'texmex', 'texaphyrin', 'quarterlight', 'sayhi', 'electrobus', 'handglide', 'webvancom', 'quarterlight', 'contemn', 'turkeycock', 'stanine', 'datahub', 'potence', 'aforewritten', 'datahub', 'nonpositive', 'aforewritten', 'choit', 'southernwort', 'indeterminism', 'longplay', 'contemn', 'greenweed', 'thickskin', 'nonsweet', 'aspca', 'roundleaf', 'pediatrist', 'nightown', 'windtight', 'undivine', 'tobem', 'plamodel', ':', 'pluse', 'lazyass', 'snapchatting', 'coalshed', 'world’s', '–', 'taxiplane', 'groundbreak', 'earball', 'magnetricity', 'tongueless', 'weating', 'sleepness', 'undivine', 'ufos', 'ttown', 'webvancom', 'hexachord', 'earball', 'bareword', 'bodycam', 'skyscrapper', 'bedbox', 'undivine', 'tornadocane', 'garderobe', 'othamologist', 'stanine', 'potence']
potence', 'aforewritten', 'datahub', 'litterbox', 'lawbook', 'nonpositive', 'aforewritten', 'blissfulness', 'choit', 'southernwort', 'sooooooo', 'contemn', 'republicrat', 'republicrat', 'greenweed', 'lawbook', 'thickskin', 'nonsweet', 'toeside', 'peacework', 'pediatrist', 'carpooler', 'libary', 'drinkery', 'nightown', 'dormroom', 'windtight', 'undivine', 'tobem', 'toolbelt', 'plasticulture', 'plamodel', 'plastisol', 'footbed', 'noisey', 'bandroom', 'belittlement', 'mirach', 'pluse', 'lazyass', 'reciepts', 'carseat', 'aquittal', 'snapchatting', 'reoccuring', 'coalshed', 'refridgerator', 'ignorable', 'unbrushed', 'world’s', 'peopple', 'taxiplane', 'groundbreak', 'litterbox', 'earball', 'magnetricity', 'maundering', 'tongueless', 'weating', 'ninty', 'storebought', 'giftwrap', 'sleepness', 'undivine', 'perambulate', 'paticular', 'carpooler', 'republicrat', 'applebees', 'ttown', 'webvancom', 'eath', 'beautifull', 'contumely', 'earball', 'bareword', 'bodycam', 'restaraunt', 'triathalon', 'bedstand', 'skyscrapper', 'bedbox', 'belittlement', 'undivine', 'tornadocane', 'wifes', 'contumely', 'othamologist', 'stanine', 'potence']

# %% [markdown]
# Obtaining Vectors

# %%
# Function to get word embeddings with handling missing words
def get_word_embedding_with_handling_missing_words(word, embedding_model):
    if word in embedding_model:
        return embedding_model[word]
    else:
        # Try lowercase
        lower_word = word.lower()
        if lower_word in embedding_model:
            return embedding_model[lower_word]
        
        # Try uppercase
        upper_word = word.upper()
        if upper_word in embedding_model:
            return embedding_model[upper_word]
        
        # Try finding a similar synonym
        try:
            synonyms = embedding_model.most_similar(word)
            for synonym, _ in synonyms:
                if synonym in embedding_model:
                    return embedding_model[synonym]
        except KeyError:
            pass
        
        # If no embedding found, return zero vector
        return np.zeros(embedding_model.vector_size)

# %%
# Represent questions using word embeddings
def represent_questions(data, cleaned_stems, cleaned_choices, embedding_model):
    representations = []
    answers = []
    for i, item in enumerate(data):
        stem = cleaned_stems[i]
        choices = [cleaned_choices[j] for j in range(i * 5, (i + 1) * 5)]
        question_representation = []
        for word in stem.split():
            embedding = get_word_embedding_with_handling_missing_words(word, embedding_model)
            if embedding is not None:
                question_representation.append(embedding)
        for choice in choices:
            for word in choice.split():
                embedding = get_word_embedding_with_handling_missing_words(word, embedding_model)
                if embedding is not None:
                    question_representation.append(embedding)
        if len(question_representation) > 0:
            representations.append(np.mean(question_representation, axis=0))
            answers.append(item['answerKey'])
    return np.array(representations), np.array(answers)

# %%
# Split data into train and test sets
X_g, y_g = represent_questions(data, cleaned_stems, cleaned_choices, glove_vectors)

X_train_g, X_test_g, y_train_g, y_test_g = train_test_split(X_g, y_g, test_size=0.2, random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_g, y_train_g)

# Evaluate model
y_pred_g = clf.predict(X_test_g)
accuracy = accuracy_score(y_test_g, y_pred_g)
print("Glove Accuracy:", accuracy)


# Split data into train and test sets
X_w, y_w = represent_questions(data, cleaned_stems, cleaned_choices, word2vec_vectors)

X_train_w, X_test_w, y_train_w, y_test_w = train_test_split(X_w, y_w, test_size=0.2, random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_w, y_train_w)

# Evaluate model
y_pred_w = clf.predict(X_test_w)
accuracy = accuracy_score(y_test_w, y_pred_w)
print("word2vec Accuracy:", accuracy)



# Split data into train and test sets
X_f, y_f = represent_questions(data, cleaned_stems, cleaned_choices, fasttext_vectors)

X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(X_f, y_f, test_size=0.2, random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_f, y_train_f)

# Evaluate model
y_pred_f = clf.predict(X_test_f)
accuracy = accuracy_score(y_test_f, y_pred_f)
print("fasttext Accuracy:", accuracy)
# Out:
# Glove Accuracy: 0.2180605438686506
# word2vec Accuracy: 0.20266803488968702
# fasttext Accuracy: 0.19189327860441252

# %% [markdown]
# ---

# %% [markdown]
# N-grams

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Represent questions using word embeddings and n-grams
def represent_questions_with_ngrams(data, cleaned_stems, cleaned_choices, embedding_model, ngram_range=(1, 1)):
    representations = []
    answers = []
    for i, item in enumerate(data):
        stem = cleaned_stems[i]
        choices = [cleaned_choices[j] for j in range(i * 5, (i + 1) * 5)]
        
        # Combine stem and choices into text for vectorization
        text = stem + ' '.join(choices)
        
        # Vectorize text using n-grams
        vectorizer = CountVectorizer(ngram_range=ngram_range)
        X = vectorizer.fit_transform([text])
        vocab = vectorizer.get_feature_names_out()
        
        # Create representations using word embeddings
        question_representation = []
        for word in vocab:
            embedding = get_word_embedding_with_handling_missing_words(word, embedding_model)
            if embedding is not None:
                question_representation.append(embedding)
        
        if len(question_representation) > 0:
            question_representation = np.mean(question_representation, axis=0)
            representations.append(question_representation)
            answers.append(item['answerKey'])
    return representations, answers

# %% [markdown]
# Uni + Bi

# %%
# Call represent_questions_with_ngrams function
X, y = represent_questions_with_ngrams(data, cleaned_stems, cleaned_choices, glove_vectors, ngram_range=(1, 2))

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)

# Evaluate model
accuracy = clf.score(X_test, y_test)
print("GloVe Accuracy:", accuracy)



#Split data into train and test sets
X_w, y_w =represent_questions_with_ngrams(data, cleaned_stems, cleaned_choices, word2vec_vectors, ngram_range=(1, 2))

X_train_w, X_test_w, y_train_w, y_test_w = train_test_split(X_w, y_w, test_size=0.2,random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_w, y_train_w)

# Evaluate model
y_pred_w = clf.predict(X_test_w)
accuracy = accuracy_score(y_test_w, y_pred_w)
print("word2vec Accuracy:", accuracy)


# Split data into train and test sets
X_f, y_f = represent_questions_with_ngrams(data, cleaned_stems, cleaned_choices, fasttext_vectors, ngram_range=(1, 2))

X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(X_f, y_f, test_size=0.2, random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_f, y_train_f)

# Evaluate model
y_pred_f = clf.predict(X_test_f)
accuracy = accuracy_score(y_test_f, y_pred_f)
print("fasttext Accuracy:", accuracy)
# Out:
# GloVe Accuracy: 0.22267829656233967
# word2vec Accuracy: 0.1944586967675731
# fasttext Accuracy: 0.19189327860441252

# %% [markdown]
# Uni + Bi + Tri

# %%
# Call represent_questions_with_ngrams function
X, y = represent_questions_with_ngrams(data, cleaned_stems, cleaned_choices, glove_vectors, ngram_range=(1, 3))

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)

# Evaluate model
accuracy = clf.score(X_test, y_test)
print("GloVe Accuracy:", accuracy)


# Split data into train and test sets
X_w, y_w =represent_questions_with_ngrams(data, cleaned_stems, cleaned_choices, word2vec_vectors, ngram_range=(1, 3))

X_train_w, X_test_w, y_train_w, y_test_w = train_test_split(X_w, y_w, test_size=0.2,random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_w, y_train_w)

# Evaluate model
y_pred_w = clf.predict(X_test_w)
accuracy = accuracy_score(y_test_w, y_pred_w)
print("word2vec Accuracy:", accuracy)


# Split data into train and test sets
X_f, y_f = represent_questions_with_ngrams(data, cleaned_stems, cleaned_choices, fasttext_vectors, ngram_range=(1, 3))

X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(X_f, y_f, test_size=0.2, random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_f, y_train_f)

# Evaluate model
y_pred_f = clf.predict(X_test_f)
accuracy = accuracy_score(y_test_f, y_pred_f)
print("fasttext Accuracy:", accuracy)
# Out:
# GloVe Accuracy: 0.21600820933812212
# word2vec Accuracy: 0.20112878399179066
# fasttext Accuracy: 0.19035402770651616

# %% [markdown]
# Uni + Bi + Tri + Quad

# %%
# Call represent_questions_with_ngrams function
X, y = represent_questions_with_ngrams(data, cleaned_stems, cleaned_choices, glove_vectors, ngram_range=(1, 4))

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)

# Evaluate model
accuracy = clf.score(X_test, y_test)
print("GloVe Accuracy:", accuracy)


# Split data into train and test sets
X_w, y_w =represent_questions_with_ngrams(data, cleaned_stems, cleaned_choices, word2vec_vectors, ngram_range=(1, 4))

X_train_w, X_test_w, y_train_w, y_test_w = train_test_split(X_w, y_w, test_size=0.2,random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_w, y_train_w)

# Evaluate model
y_pred_w = clf.predict(X_test_w)
accuracy = accuracy_score(y_test_w, y_pred_w)
print("word2vec Accuracy:", accuracy)


# Split data into train and test sets
X_f, y_f = represent_questions_with_ngrams(data, cleaned_stems, cleaned_choices, fasttext_vectors, ngram_range=(1, 4))

X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(X_f, y_f, test_size=0.2, random_state=0)

# Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_f, y_train_f)

# Evaluate model
y_pred_f = clf.predict(X_test_f)
accuracy = accuracy_score(y_test_f, y_pred_f)
print("fasttext Accuracy:", accuracy)
# Out:
# GloVe Accuracy: 0.21600820933812212
# word2vec Accuracy: 0.2072857875833761
# fasttext Accuracy: 0.18624935864545922

# %% [markdown]
# ---

# %% [markdown]
# Exploring gensim more ...

# %%
# access the 'word2vec-google-news-300' embeddings as KeyedVectors
model = word2vec_vectors

# Get the list of words
words = model.index_to_key

# Print a sample of words
sample_size = 100
print("Sample Words:")
for word in words[:sample_size]:
    print(word)
# Out:
# Sample Words:
# </s>
# in
# for
# that
# is
# on
# ##
# The
# with
# said
# was
# the
# at
# not
# as
# it
# be
# from
# by
# are
# I
# have
# he
# will
# has
# ####
# his
# an
# this
# or
# their
# who
# they
# but
# $
# had
# year
# were
# we
# more
# ###
# up
# been
# you
# its
# one
# about
# would
# which
# out
# can
# It
# all
# also
# two
# after
# first
# He
# do
# time
# than
# when
# We
# over
# last
# new
# other
# her
# people
# into
# In
# our
# there
# A
# she
# could
# just
# years
# some
# U.S.
# three
# million
# them
# what
# But
# so
# no
# like
# if
# only
# percent
# get
# did
# him
# game
# back
# because
# now
# #.#
# before

# %%
# Get the list of words
words = word2vec_vectors.index_to_key

# Print the word vectors for a sample of words
sample_size = 10  
print("Word Vectors:")
for word in words[:sample_size]:
    print(f"{word}: {word2vec_vectors[word]}")
# Out:
# Word Vectors:
# </s>: [ 1.1291504e-03 -8.9645386e-04  3.1852722e-04  1.5335083e-03
#   1.1062622e-03 -1.4038086e-03 -3.0517578e-05 -4.1961670e-04
#  -5.7601929e-04  1.0757446e-03 -1.0223389e-03 -6.1798096e-04
